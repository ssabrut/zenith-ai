# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
import os
from langchain_community.chat_models import ChatDeepInfra

DEEPINFRA_API_TOKEN = os.environ.get("DEEPINFRA_API_TOKEN")
deepinfra_client = ChatDeepInfra(
    model="openai/gpt-oss-20b",
    deepinfra_api_token=DEEPINFRA_API_TOKEN
)

# %%
from langchain_core.messages import HumanMessage

messages = [HumanMessage(content="How are you?")]
response = deepinfra_client.generate([messages])
print(response)
# Out:
# generations=[[ChatGeneration(text='I’m doing well—thanks for asking! How about you? 😊', generation_info={'finish_reason': 'stop'}, message=AIMessage(content='I’m doing well—thanks for asking! How about you? 😊', additional_kwargs={}, response_metadata={'token_usage': {'prompt_tokens': 58, 'total_tokens': 157, 'completion_tokens': 99, 'estimated_cost': 1.5600000000000003e-05, 'prompt_tokens_details': None}, 'model': 'openai/gpt-oss-20b', 'finish_reason': 'stop'}, id='lc_run--550ce00f-a7c4-4cfe-aebf-f6d0bf217efc-0'))]] llm_output={} run=[RunInfo(run_id=UUID('550ce00f-a7c4-4cfe-aebf-f6d0bf217efc'))] type='LLMResult'
